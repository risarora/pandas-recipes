# %%
                                                                                                                                                                                                                                                                                                        import pandas as pd

# %%
movie = pd.read_csv('./data/movie.csv',index_col='movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %% [markdown]
# ##### Note
#     The DataFrame indexing operator is capable of accepting a number of different objects.
#     If a string is passed, it will return a single-dimensional Series.
#     If a list is passed to the indexing operator, it returns a DataFrame of all the columns in the list in the specified order

# %%
#### Selecting multiple DataFrame columns

# %%
movie_actor_director = movie[['actor_1_name', 'actor_2_name',
                                  'actor_3_name', 'director_name']]
movie_actor_director.head()
# Out:
#                                                actor_1_name      actor_2_name  \
# movie_title
# Avatar                                          CCH Pounder  Joel David Moore
# Pirates of the Caribbean: At World's End        Johnny Depp     Orlando Bloom
# Spectre                                     Christoph Waltz      Rory Kinnear
# The Dark Knight Rises                             Tom Hardy    Christian Bale
# Star Wars: Episode VII - The Force Awakens      Doug Walker        Rob Walker
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                                 director_name
# movie_title
# ...

# %%
# Fetching Columns with a List
cols = ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']
movie_actor_director = movie[cols]
movie_actor_director.head()
# Out:
#                                                actor_1_name      actor_2_name  \
# movie_title
# Avatar                                          CCH Pounder  Joel David Moore
# Pirates of the Caribbean: At World's End        Johnny Depp     Orlando Bloom
# Spectre                                     Christoph Waltz      Rory Kinnear
# The Dark Knight Rises                             Tom Hardy    Christian Bale
# Star Wars: Episode VII - The Force Awakens      Doug Walker        Rob Walker
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                                 director_name
# movie_title
# ...

# %%
#### Selecting columns with methods

# %%
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     11
# dtype: int64

# %%
# Fetcing columns of type 'object'
movie.select_dtypes(include=['object']).head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                                                      genres  \
# movie_title
# ...

# %%
# Fetcing columns of type 'int64'
movie.select_dtypes(include=['int64']).head()
# Out:
#                                             num_voted_users  \
# movie_title
# Avatar                                               886204
# Pirates of the Caribbean: At World's End             471220
# Spectre                                              275868
# The Dark Knight Rises                               1144337
# Star Wars: Episode VII - The Force Awakens                8
#
#                                             cast_total_facebook_likes  \
# movie_title
# Avatar                                                           4834
# Pirates of the Caribbean: At World's End                        48350
# Spectre                                                         11700
# The Dark Knight Rises                                          106759
# Star Wars: Episode VII - The Force Awakens                        143
#
#                                             movie_facebook_likes
# movie_title
# Avatar                                                     33000
# ...

# %%
#movie.select_dtypes(include='np.number').head()

# %%
# Filter columns with string 'name'
movie.filter(like='name').head()
# Out:
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                                 actor_2_name     actor_1_name  \
# movie_title
# Avatar                                      Joel David Moore      CCH Pounder
# Pirates of the Caribbean: At World's End       Orlando Bloom      Johnny Depp
# Spectre                                         Rory Kinnear  Christoph Waltz
# The Dark Knight Rises                         Christian Bale        Tom Hardy
# Star Wars: Episode VII - The Force Awakens        Rob Walker      Doug Walker
#
#                                                     actor_3_name
# movie_title
# ...

# %%
# Filter columns with digit in name 
movie.filter(regex='\d').head()
# Out:
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# ...

# %% [markdown]
# #### Ordering column names sensibly
# 1. Classify each column as either discrete or continuous
# 2. Group common columns within the discrete and continuous columns
# 3. Place the most important groups of columns first with categorical columns before continuous ones

# %%
movie=pd.read_csv('data/movie.csv')

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
>>> disc_core = ['movie_title', 'title_year',
                 'content_rating', 'genres']
>>> disc_people = ['director_name', 'actor_1_name', 
                   'actor_2_name', 'actor_3_name']
>>> disc_other = ['color', 'country', 'language', 
                  'plot_keywords', 'movie_imdb_link']

>>> cont_fb = ['director_facebook_likes', 'actor_1_facebook_likes', 
               'actor_2_facebook_likes', 'actor_3_facebook_likes',
               'cast_total_facebook_likes', 'movie_facebook_likes']

>>> cont_finance = ['budget', 'gross']
>>> cont_num_reviews = ['num_voted_users', 'num_user_for_reviews',
                        'num_critic_for_reviews']
>>> cont_other = ['imdb_score', 'duration',
                  'aspect_ratio', 'facenumber_in_poster']

# %%
>>> new_col_order = disc_core + disc_people + \
                    disc_other + cont_fb + \
                    cont_finance + cont_num_reviews + \
                    cont_other

# %%
>>> set(movie.columns) == set(new_col_order)
# Out:
# True

# %%
movie2 = movie[new_col_order]
movie2.head()
# Out:
#                                   movie_title  title_year content_rating  \
# 0                                      Avatar      2009.0          PG-13
# 1    Pirates of the Caribbean: At World's End      2007.0          PG-13
# 2                                     Spectre      2015.0          PG-13
# 3                       The Dark Knight Rises      2012.0          PG-13
# 4  Star Wars: Episode VII - The Force Awakens         NaN            NaN
#
#                             genres      director_name     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# 1         Action|Adventure|Fantasy     Gore Verbinski      Johnny Depp
# 2        Action|Adventure|Thriller         Sam Mendes  Christoph Waltz
# 3                  Action|Thriller  Christopher Nolan        Tom Hardy
# 4                      Documentary        Doug Walker      Doug Walker
#
#        actor_2_name          actor_3_name  color country  \
# ...

# %% [markdown]
# ##### Operating on the entire DataFrame

# %%
movie = pd.read_csv('data/movie.csv')
print ('movie.shape',movie.shape)
print ('movie.size',movie.size)
print ('movie.ndim',movie.ndim)
print ('len(movie)',len(movie))
# Out:
# movie.shape (4916, 28)
# movie.size 137648
# movie.ndim 2
# len(movie) 4916

# %%
movie.count().head()
# Out:
# color                      4897
# director_name              4814
# num_critic_for_reviews     4867
# duration                   4901
# director_facebook_likes    4814
# dtype: int64

# %%
movie.min(skipna=True).head()
# Out:
# num_critic_for_reviews     1.0
# duration                   7.0
# director_facebook_likes    0.0
# actor_3_facebook_likes     0.0
# actor_1_facebook_likes     0.0
# dtype: float64

# %%
movie.min(skipna=False).head()
# Out:
# C:\Tools\Anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# num_critic_for_reviews    NaN
# duration                  NaN
# director_facebook_likes   NaN
# actor_3_facebook_likes    NaN
# actor_1_facebook_likes    NaN
# dtype: float64

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie.describe(percentiles=[.01, .3, .99])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 1%                   2.000000    43.000000                 0.000000
# 30%                 60.000000    95.000000                11.000000
# 50%                108.000000   103.000000                48.000000
# 99%                546.680000   189.000000             16000.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# ...

# %%
# Specify exact quantiles in the describe method using the percentiles parameter:
movie.describe(percentiles=[.1, .3, .9])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 10%                 17.000000    86.000000                 0.000000
# 30%                 60.000000    95.000000                11.000000
# 50%                108.000000   103.000000                48.000000
# 90%                294.000000   134.000000               545.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# ...

# %% [markdown]
# #### Chaining DataFrame methods together

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.isnull().head()
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  False          False                   False     False
# 1  False          False                   False     False
# 2  False          False                   False     False
# 3  False          False                   False     False
# 4   True          False                    True      True
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                    False                   False         False
# 1                    False                   False         False
# 2                    False                   False         False
# 3                    False                   False         False
# 4                    False                    True         False
#
#    actor_1_facebook_likes  gross  genres          ...           \
# 0                   False  False   False          ...
# 1                   False  False   False          ...
# ...

# %%
movie.isnull().sum().head()
# Out:
# color                       19
# director_name              102
# num_critic_for_reviews      49
# duration                    15
# director_facebook_likes    102
# dtype: int64

# %%
movie.isnull().sum().sum()
# Out:
# 2654

# %%
#print('movie.isnull() :',movie.isnull())
print('movie.isnull().any()head() ')
print(movie.isnull().any().head())
print('\n')
print('movie.isnull().any().any() :',movie.isnull().any().any())
# Out:
# movie.isnull().any()head()
# color                      True
# director_name              True
# num_critic_for_reviews     True
# duration                   True
# director_facebook_likes    True
# dtype: bool
#
#
# movie.isnull().any().any() : True

# %%
movie.isnull().head()
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  False          False                   False     False
# 1  False          False                   False     False
# 2  False          False                   False     False
# 3  False          False                   False     False
# 4   True          False                    True      True
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                    False                   False         False
# 1                    False                   False         False
# 2                    False                   False         False
# 3                    False                   False         False
# 4                    False                    True         False
#
#    actor_1_facebook_likes  gross  genres          ...           \
# 0                   False  False   False          ...
# 1                   False  False   False          ...
# ...

# %%
movie.isnull().get_dtype_counts()
# Out:
# bool    28
# dtype: int64

# %%
#TBD 
movie[['color', 'movie_title']].max()
# Out:
# Series([], dtype: float64)

# %%
movie.select_dtypes(['object']).fillna('').min()
# Out:
# color
# director_name
# actor_2_name
# genres                                                        Action
# actor_1_name
# movie_title                                                  #Horror
# actor_3_name
# plot_keywords
# movie_imdb_link    http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# language
# country
# content_rating
# dtype: object

# %%
movie.select_dtypes(['object']) \
         .fillna('') \
         .min()
# Out:
# color
# director_name
# actor_2_name
# genres                                                        Action
# actor_1_name
# movie_title                                                  #Horror
# actor_3_name
# plot_keywords
# movie_imdb_link    http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# language
# country
# content_rating
# dtype: object

# %% [markdown]
# #### Working with operators on a DataFrame

# %%
college = pd.read_csv('data/college.csv',index_col='INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college_ugds = college.filter(like='UGDS_')

# %%
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# Adding a value to all cells in selected columns
(college_ugds + 0.00501).head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                0.03831     0.94031    0.01051
# University of Alabama at Birmingham     0.59721     0.26501    0.03331
# Amridge University                      0.30401     0.42421    0.01191
# University of Alabama in Huntsville     0.70381     0.13051    0.04321
# Alabama State University                0.02081     0.92581    0.01711
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                0.00691    0.00741    0.00691
# University of Alabama at Birmingham     0.05681    0.00721    0.00571
# Amridge University                      0.00841    0.00501    0.00501
# University of Alabama in Huntsville     0.04261    0.01931    0.00521
# Alabama State University                0.00691    0.00601    0.00561
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# Adding a value to all cells in selected columns
((college_ugds + 0.00501) // .01).head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                    3.0        94.0        1.0
# University of Alabama at Birmingham        59.0        26.0        3.0
# Amridge University                         30.0        42.0        1.0
# University of Alabama in Huntsville        70.0        13.0        4.0
# Alabama State University                    2.0        92.0        1.0
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                    0.0        0.0        0.0
# University of Alabama at Birmingham         5.0        0.0        0.0
# Amridge University                          0.0        0.0        0.0
# University of Alabama in Huntsville         4.0        1.0        0.0
# Alabama State University                    0.0        0.0        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
print('college_ugds.isnull().any()head() ')
print(college_ugds.isnull().any().head())
# Out:
# college_ugds.isnull().any()head()
# UGDS_WHITE    True
# UGDS_BLACK    True
# UGDS_HISP     True
# UGDS_ASIAN    True
# UGDS_AIAN     True
# dtype: bool

# %%
0/100
# Out:
# 0.0

# %%
import pandas as pd 
college = pd.read_csv('data/college.csv',index_col='INSTNM')

college_ugds_head = college.filter(like='UGDS_').head()
college_ugds = college_ugds.fillna(0)

college_ugds_op_round = (college_ugds + 0.00501) // .01
#college_ugds_op_round.div(2)
#college_ugds_op_round = (college_ugds + 0.00501) // .01 /100

#college_ugds_op_round.head()

# %%
college_ugds_op_round.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                    3.0        94.0        1.0
# University of Alabama at Birmingham        59.0        26.0        3.0
# Amridge University                         30.0        42.0        1.0
# University of Alabama in Huntsville        70.0        13.0        4.0
# Alabama State University                    2.0        92.0        1.0
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                    0.0        0.0        0.0
# University of Alabama at Birmingham         5.0        0.0        0.0
# Amridge University                          0.0        0.0        0.0
# University of Alabama in Huntsville         4.0        1.0        0.0
# Alabama State University                    0.0        0.0        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# >>> college_ugds_op_round = (college_ugds+ .00501) // .01 / 100
# >>> college_ugds_op_round.head()

# %%
college_ugds_round = (college_ugds + .00001).round(2)
college_ugds_round.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                   0.03        0.94       0.01
# University of Alabama at Birmingham        0.59        0.26       0.03
# Amridge University                         0.30        0.42       0.01
# University of Alabama in Huntsville        0.70        0.13       0.04
# Alabama State University                   0.02        0.92       0.01
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                   0.00       0.00        0.0
# University of Alabama at Birmingham        0.05       0.00        0.0
# Amridge University                         0.00       0.00        0.0
# University of Alabama in Huntsville        0.04       0.01        0.0
# Alabama State University                   0.00       0.00        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds_op_round.equals(college_ugds_round)
# Out:
# False

# %%
xxx= college_ugds.add(.00501).floordiv(0.01)

# %%
xxx.div(100)

# %%
college_ugds_op_round_methods = college_ugds.add(.00501) \
                                                 .floordiv(.01) \
                                                 .div(100)
college_ugds_op_round_methods.equals(college_ugds_op_round)

# %%
import pandas as pd 
college = pd.read_csv('data/college.csv',index_col='INSTNM')

college_ugds = college.filter(like='UGDS_')
college_ugds = college_ugds.fillna(0)

college_ugds_op_round = (college_ugds + 0.00501) // .01
college_ugds_op_round
#college_ugds_op_round.div(2)
#college_ugds_op_round = (college_ugds + 0.00501) // .01 /100

#college_ugds_op_round.head()
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                   3.0        94.0
# University of Alabama at Birmingham                       59.0        26.0
# Amridge University                                        30.0        42.0
# University of Alabama in Huntsville                       70.0        13.0
# Alabama State University                                   2.0        92.0
# The University of Alabama                                 78.0        11.0
# Central Alabama Community College                         73.0        26.0
# Athens State University                                   78.0        12.0
# Auburn University at Montgomery                           53.0        34.0
# Auburn University                                         85.0         7.0
# Birmingham Southern College                               80.0        11.0
# ...

# %%
college = pd.read_csv('data/college.csv',index_col='INSTNM')
college_ugds = college.filter( like='UGDS_')
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds.isnull().sum()
# Out:
# UGDS_WHITE    661
# UGDS_BLACK    661
# UGDS_HISP     661
# UGDS_ASIAN    661
# UGDS_AIAN     661
# UGDS_NHPI     661
# UGDS_2MOR     661
# UGDS_NRA      661
# UGDS_UNKN     661
# dtype: int64

# %%
college_ugds = college_ugds.fillna(0)
college_ugds.isnull().sum()
# Out:
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
# college_ugds = college_ugds.div(100)

# %% [markdown]
# #### Comparing missing values

# %%
import numpy as np

# %%
print('np.nan == np.nan',np.nan == np.nan)
print('None == None',None == None)
print('#All other comparisons against np.nan also return False, except not equal to:')
print('np.nan > 5',np.nan > 5)
print('5 > np.nan',5 > np.nan)
print('np.nan!=5',np.nan != 5)
# Out:
# np.nan == np.nan False
# None == None True
# #All other comparisons against np.nan also return False, except not equal to:
# np.nan > 5 False
# 5 > np.nan False
# np.nan!=5 True

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
college_ugds_ = college.filter(like='UGDS_')

# %%
(college_ugds_ < 0.5).head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                   True       False       True
# University of Alabama at Birmingham       False        True       True
# Amridge University                         True        True       True
# University of Alabama in Huntsville       False        True       True
# Alabama State University                   True       False       True
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                   True       True       True
# University of Alabama at Birmingham        True       True       True
# Amridge University                         True       True       True
# University of Alabama in Huntsville        True       True       True
# Alabama State University                   True       True       True
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
(college_ugds_ < 0.5).sum()
# Out:
# UGDS_WHITE    3030
# UGDS_BLACK    6141
# UGDS_HISP     6291
# UGDS_ASIAN    6839
# UGDS_AIAN     6835
# UGDS_NHPI     6865
# UGDS_2MOR     6873
# UGDS_NRA      6861
# UGDS_UNKN     6807
# dtype: int64

# %%
# Comparping Values to null retrns False 
(college_ugds_==np.nan).sum()
# Out:
# UGDS_WHITE    0
# UGDS_BLACK    0
# UGDS_HISP     0
# UGDS_ASIAN    0
# UGDS_AIAN     0
# UGDS_NHPI     0
# UGDS_2MOR     0
# UGDS_NRA      0
# UGDS_UNKN     0
# dtype: int64

# %%
# Comparping Values to null retrns False 
college_ugds_.isnull().sum()
# Out:
# UGDS_WHITE    661
# UGDS_BLACK    661
# UGDS_HISP     661
# UGDS_ASIAN    661
# UGDS_AIAN     661
# UGDS_NHPI     661
# UGDS_2MOR     661
# UGDS_NRA      661
# UGDS_UNKN     661
# dtype: int64

# %%
# Compare two dat sets with one another is by comparing them using '.equals()' operator
college_ugds_.equals(college_ugds_)
# Out:
# True

# %%
#### Transposing the direction of a DataFrame operation

# %%
import pandas as pd 
college = pd.read_csv('data/college.csv', index_col='INSTNM')
college_ugds_ = college.filter(like='UGDS_')
college_ugds_.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
# The count method returns the number of non-missing values. By default, its axis parameter is set to 0:
college_ugds_.count()
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
college_ugds_.count(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               9
# University of Alabama at Birmingham    9
# Amridge University                     9
# University of Alabama in Huntsville    9
# Alabama State University               9
# dtype: int64

# %%
# Instead of counting non-missing values, we can sum all the values in each row. 
# Each row of percentages should add up to 1. The sum method may be used to verify this:
college_ugds_.sum(axis='columns').head()
# Out:
# INSTNM
# Alabama A & M University               1.0000
# University of Alabama at Birmingham    0.9999
# Amridge University                     1.0000
# University of Alabama in Huntsville    1.0000
# Alabama State University               1.0000
# dtype: float64

# %%
college_ugds_.cumsum(axis=1)
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                0.0333      0.9686
# University of Alabama at Birmingham                     0.5922      0.8522
# Amridge University                                      0.2990      0.7182
# University of Alabama in Huntsville                     0.6988      0.8243
# Alabama State University                                0.0158      0.9366
# The University of Alabama                               0.7825      0.8944
# Central Alabama Community College                       0.7255      0.9868
# Athens State University                                 0.7823      0.9023
# Auburn University at Montgomery                         0.5328      0.8704
# Auburn University                                       0.8507      0.9211
# Birmingham Southern College                             0.7983      0.9085
# ...

# %%
#To get an idea of the distribution of each column, the median method can be used:

college_ugds_.median(axis='index')
# Out:
# UGDS_WHITE    0.55570
# UGDS_BLACK    0.10005
# UGDS_HISP     0.07140
# UGDS_ASIAN    0.01290
# UGDS_AIAN     0.00260
# UGDS_NHPI     0.00000
# UGDS_2MOR     0.01750
# UGDS_NRA      0.00000
# UGDS_UNKN     0.01430
# dtype: float64

# %%
#### Determining college campus diversity
